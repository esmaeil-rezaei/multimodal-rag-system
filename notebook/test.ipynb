# %%
from contextvars import ContextVar

# %%
_correlation_id = ContextVar("_correlation_id", default="no-request-context")

# %%
import uuid
_correlation_id.set(str(uuid.uuid4()))
# Out:
# <Token var=<ContextVar name='_correlation_id' default='no-request-context' at 0x10ef67650> at 0x10ef2d200>

# %%
uuid.uuid4()
# Out:
# UUID('5bf5eeab-f0e8-4b8e-b228-478778efd4e1')
